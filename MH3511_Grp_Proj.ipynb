# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswi002/NY-Housing-Mkt-Analysis/blob/main/MH3511_Grp_Proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nyhd = read.csv('NY-House-Dataset.csv', header = TRUE)

# %%
str(nyhd)
# Out:
# 'data.frame':	4801 obs. of  17 variables:
#  $ BROKERTITLE                : chr  "Brokered by Douglas Elliman  -111 Fifth Ave" "Brokered by Serhant" "Brokered by Sowae Corp" "Brokered by COMPASS" ...
#  $ TYPE                       : chr  "Condo for sale" "Condo for sale" "House for sale" "Condo for sale" ...
#  $ PRICE                      : int  315000 195000000 260000 69000 55000000 690000 899500 16800000 265000 440000 ...
#  $ BEDS                       : int  2 7 4 3 7 5 2 8 1 2 ...
#  $ BATH                       : num  2 10 2 1 2.37 ...
#  $ PROPERTYSQFT               : num  1400 17545 2015 445 14175 ...
#  $ ADDRESS                    : chr  "2 E 55th St Unit 803" "Central Park Tower Penthouse-217 W 57th New York St Unit Penthouse" "620 Sinclair Ave" "2 E 55th St Unit 908W33" ...
#  $ STATE                      : chr  "New York, NY 10022" "New York, NY 10019" "Staten Island, NY 10312" "Manhattan, NY 10022" ...
# ...

# %%
summary(nyhd)
# Out:
#  BROKERTITLE            TYPE               PRICE                BEDS
#  Length:4801        Length:4801        Min.   :2.494e+03   Min.   : 1.000
#  Class :character   Class :character   1st Qu.:4.990e+05   1st Qu.: 2.000
#  Mode  :character   Mode  :character   Median :8.250e+05   Median : 3.000
#                                        Mean   :2.357e+06   Mean   : 3.357
#                                        3rd Qu.:1.495e+06   3rd Qu.: 4.000
#                                        Max.   :2.147e+09   Max.   :50.000
#       BATH         PROPERTYSQFT     ADDRESS             STATE
#  Min.   : 0.000   Min.   :  230   Length:4801        Length:4801
#  1st Qu.: 1.000   1st Qu.: 1200   Class :character   Class :character
#  Median : 2.000   Median : 2184   Mode  :character   Mode  :character
#  Mean   : 2.374   Mean   : 2184
#  3rd Qu.: 3.000   3rd Qu.: 2184
#  Max.   :50.000   Max.   :65535
#  MAIN_ADDRESS       ADMINISTRATIVE_AREA_LEVEL_2   LOCALITY
# ...

# %% [markdown]
# #DATA CLEANING

# %% [markdown]
# Checking for NULL Values in the dataset

# %%
colSums(is.na(nyhd))
# No missing data in this dataset
# Out:
#                 BROKERTITLE                        TYPE
#                           0                           0
#                       PRICE                        BEDS
#                           0                           0
#                        BATH                PROPERTYSQFT
#                           0                           0
#                     ADDRESS                       STATE
#                           0                           0
#                MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2
#                           0                           0
#                    LOCALITY                 SUBLOCALITY
#                           0                           0
#                 STREET_NAME                   LONG_NAME
#                           0                           0
#           FORMATTED_ADDRESS                    LATITUDE
#                           0                           0
#                   LONGITUDE
#                           0

# %% [markdown]
# Removing unneeded colums - mainly categorical variables with too many types

# %%
#Im jst testing my code. We can change the columns chosen during the meeting
drop <- c("BROKERTITLE","MAIN_ADDRESS")
df_ny = nyhd[,!(names(nyhd) %in% drop)]
str(df_ny)
# Out:
# 'data.frame':	4801 obs. of  15 variables:
#  $ TYPE                       : chr  "Condo for sale" "Condo for sale" "House for sale" "Condo for sale" ...
#  $ PRICE                      : int  315000 195000000 260000 69000 55000000 690000 899500 16800000 265000 440000 ...
#  $ BEDS                       : int  2 7 4 3 7 5 2 8 1 2 ...
#  $ BATH                       : num  2 10 2 1 2.37 ...
#  $ PROPERTYSQFT               : num  1400 17545 2015 445 14175 ...
#  $ ADDRESS                    : chr  "2 E 55th St Unit 803" "Central Park Tower Penthouse-217 W 57th New York St Unit Penthouse" "620 Sinclair Ave" "2 E 55th St Unit 908W33" ...
#  $ STATE                      : chr  "New York, NY 10022" "New York, NY 10019" "Staten Island, NY 10312" "Manhattan, NY 10022" ...
#  $ ADMINISTRATIVE_AREA_LEVEL_2: chr  "New York County" "United States" "United States" "United States" ...
#  $ LOCALITY                   : chr  "New York" "New York" "New York" "New York" ...
# ...

# %% [markdown]
# Removing Duplicate Entries

# %%
duplicated(df_ny)
sum(duplicated(df_ny))
# There are 214 duplicate rows in this dataset
# Out:
#    [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE
#   [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE
#  [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
ny_unique <- unique(df_ny)

# %%
duplicated(ny_unique)
sum(duplicated(ny_unique))
# All the duplicates have been removed
# Out:
#    [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
beds <- nyhd$BEDS
bath <- nyhd$BATH
p_sqft <- nyhd$PROPERTYSQFT
